# %% [markdown]
#     TWO STACKS

# %% [markdown]
# 1. two stacks Fixed Size

# %%
class TwostacksFixed:
    def __init__(self, size):
        self.size = size
        self.stack = [None]*size
        self.top1 = -1
        self.mid = size//2
        self.top2 = self.mid - 1

    def push1(self, variable):
        # if self.top1 + 1 == self.mid + 1:
        #     return "Overflow"
        # else:
        #     self.top1 +=1 
        #     self.stack[self.top1] = variable
        #     return f"added {variable}"
        if self.top1+1 >= self.mid:
            raise OverflowError("Stack is Overflow")  #raising an error in Python
        else:
            self.top1 += 1 
            self.stack[self.top1] = variable
            return "pushed"
    
    def push2(self, variable):
        if self.top2 + 1 >= self.size:
            raise OverflowError("Stack is Overflow")
        else:
            self.top2 += 1
            self.stack[self.top2] = variable
            return "pushed"
    
    def display(self):
        print("Array", self.stack)
        print("Stack1:", self.stack[:self.top1+1])
        print("Stack2:", self.stack[self.mid:self.top2+1])
        
    def pop1(self):
        if self.top1 == -1:      # to check if stack is empty
            return "UnderFlow"
        else:
            x = self.stack[self.top1]
            self.top1 -= 1
            return f"popped {x}"
    
    def pop2(self):
        if self.top2:
            return "underFlow"
        else:
            x = self.stack[self.top1]
            self.top -= 1
            return f"popped {x}"
    

s = TwostacksFixed(10)

print(s.push1(10))
print(s.push2(20))
print(s.push1(30))
print(s.push1(90))
print(s.push1(10))
s.display()
print(s.pop1())
# Out:
# pushed
# pushed
# pushed
# pushed
# pushed
# Array [10, 30, 90, 10, None, 20, None, None, None, None]
# Stack1: [10, 30, 90, 10]
# Stack2: [20]
# popped 10
